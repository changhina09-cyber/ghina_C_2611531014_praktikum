# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **"PROGRAM ARITMATIKA, BITWISE, LOGIKA, dan PERBANDINGAN”**
#
# **Disusun Oleh :**
#
# **Ghina Ranianda Husni**
#
# **2611531014**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Alvero**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum ... yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan ...
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep program artimatika, bitwise, logika, dan perbandingan pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Dalam pemrograman, operator merupakan konsep dasar yang penting untuk dipelajari karena digunakan untuk mengolah data, melakukan perhitungan, membandingkan nilai, serta menentukan suatu kondisi. Pemahaman terhadap operator menjadi dasar dalam membuat program yang dapat bekerja sesuai dengan kebutuhan. Tanpa memahami operator, proses seperti menghitung data, menentukan keputusan, dan mengatur kondisi dalam sebuah program akan menjadi lebih sulit.
#
# Operator aritmatika adalah operator yang digunakan untuk melakukan perhitungan matematika, seperti penjumlahan, pengurangan, perkalian, pembagian, dan sisa pembagian. Operator ini banyak digunakan dalam pemrograman, misalnya untuk menghitung total harga, diskon, rata-rata, dan berbagai proses perhitungan lainnya. Operator perbandingan digunakan untuk membandingkan dua nilai dan menghasilkan "True" atau "False". Operator ini biasanya digunakan untuk menentukan apakah suatu kondisi terpenuhi, seperti memeriksa batas harga atau jumlah barang.
#
# Operator logika digunakan untuk menggabungkan beberapa kondisi menggunakan "and", "or", dan "not". Operator ini sangat berguna dalam proses pengambilan keputusan, misalnya menentukan apakah pelanggan mendapatkan diskon berdasarkan beberapa persyaratan. Sementara itu, operator bitwise digunakan untuk melakukan operasi pada data dalam bentuk bit atau bilangan biner. Operator seperti "&", "|", dan "^" dapat digunakan untuk menggabungkan, memeriksa, atau membandingkan kondisi yang direpresentasikan dalam bentuk biner.
#
# Keempat jenis operator tersebut memiliki peran yang berbeda, tetapi dapat digunakan secara bersamaan dalam sebuah program. Dalam program transaksi toko, misalnya, operator aritmatika digunakan untuk menghitung harga dan diskon, operator perbandingan untuk memeriksa syarat transaksi, operator logika untuk menggabungkan beberapa persyaratan, dan operator bitwise untuk mengolah kode status pelanggan. Oleh karena itu, mempelajari operator aritmatika, perbandingan, logika, dan bitwise penting untuk membangun pemahaman dasar pemrograman serta membuat program yang dapat mengolah data dan mengambil keputusan dengan benar.
#
# ## 1.2 Tujuan
# 1. Memahami pengertian dan fungsi operator aritmatika, perbandingan, logika, dan bitwise dalam Python.
# 2. Mampu menerapkan berbagai operator untuk melakukan perhitungan dan pemeriksaan kondisi dalam program.
# 3. Mampu menggabungkan operator aritmatika, perbandingan, logika, dan bitwise dalam satu program untuk menyelesaikan suatu permasalahan.
# 4. Meningkatkan kemampuan dalam membuat dan memahami alur program Python yang terstruktur dan sesuai dengan kebutuhan.
#
# ## 1.3 Manfaat
# 1. Menambah pemahaman tentang penggunaan operator aritmatika, perbandingan, logika, dan bitwise dalam Python.
# 2. Melatih kemampuan dalam melakukan perhitungan dan pengolahan data menggunakan program.
# 3. Membantu memahami cara membuat keputusan berdasarkan kondisi tertentu dalam sebuah program.
# 4. Meningkatkan kemampuan dalam membuat program Python yang lebih terstruktur dan dapat digunakan untuk menyelesaikan permasalahan sederhana.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# 1. Operator Aritmatika
# Operator aritmatika merupakan operator yang digunakan untuk melakukan perhitungan matematika dalam Python. Operator yang digunakan antara lain + untuk penjumlahan, - untuk pengurangan, * untuk perkalian, / untuk pembagian, // untuk pembagian bilangan bulat, % untuk mencari sisa pembagian, dan ** untuk perpangkatan. Dalam program transaksi, operator aritmatika dapat digunakan untuk menghitung diskon, total pembayaran, dan harga rata-rata barang.
#
# 2. Operator Perbandingan
# Operator perbandingan digunakan untuk membandingkan dua nilai. Hasil dari perbandingan berupa True atau False. Beberapa operator perbandingan yaitu ==, !=, >, <, >=, dan <=. Dalam program transaksi, operator ini dapat digunakan untuk memeriksa apakah total belanja sudah mencapai Rp200.000 atau apakah jumlah barang sudah memenuhi minimal 3 barang.
#
# 3. Operator Logika
# Operator logika digunakan untuk menggabungkan atau membalik beberapa kondisi. Operator and menghasilkan True jika semua kondisi terpenuhi, or menghasilkan True jika salah satu kondisi terpenuhi, sedangkan not digunakan untuk membalik hasil suatu kondisi. Dalam program transaksi, operator logika dapat digunakan untuk menentukan apakah pelanggan mendapatkan diskon berdasarkan status member, jumlah belanja, atau ketersediaan promo.
#
# 4. Operator Bitwise
# Operator bitwise merupakan operator yang digunakan untuk melakukan operasi terhadap bilangan berdasarkan bentuk biner atau bit. Beberapa operator bitwise yang digunakan adalah & untuk AND, | untuk OR, ^ untuk XOR, << untuk menggeser bit ke kiri, dan >> untuk menggeser bit ke kanan. Dalam program transaksi, operator bitwise dapat digunakan untuk membuat kode status pelanggan berdasarkan beberapa kondisi, seperti status member, jumlah belanja, jumlah barang, dan ketersediaan kode promo.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "C_2611531014"

# %%
# Buat file dengan nama aritmatika_2611531014.py
# Buat program untuk operator aritmatika dalam python
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1014
# program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

angka1_1014 = int(input("input angka-1: "))
angka2_1014 = int(input("input angka-2: "))

# Penjumlahan
hasil = angka1_1014 + angka2_1014
print("\nOperator Penjumlahan")
print("Hasil =", hasil)

# Pengurangan 
hasil = angka1_1014 - angka2_1014
print("\nOperator Pengurangan")
print("Hasil =", hasil)

# Perkalian 
hasil = angka1_1014 * angka2_1014
print("\nOperator Perkalian")
print("Hasil =", hasil)

# Pembagian, pembagian bulat, dan sisa bagi
if angka2_1014 != 0:
    hasil = angka1_1014 / angka2_1014
    print("\nOperator Pembagian")
    print("Hasil=", hasil)

    hasil = angka1_1014 // angka2_1014
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil)

    hasil = angka1_1014 % angka2_1014
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil)
else:
    print("Angka kedua tidak boleh bernilai 0.")

# Pangkat
hasil = angka1_1014 ** angka2_1014
print("\nOperator Pangkat")
print("Hasil =", hasil)

# %% [markdown]
# **Penjelasan :**
# 1. Komentar & Petunjuk: Baris diawali # berisi dokumen petunjuk tugas, penamaan file aritmatika_2611531014.py, aturan variabel bernama NIM 1014, serta instruksi pemrosesan input.
#
# 2. Input & Konversi Data: Baris int(input(...)) menerima nilai dari pengguna via keyboard yang semula bertipe string, lalu dikonversi langsung menjadi bilangan bulat (integer) untuk disimpan ke variabel angka1_1014 dan angka2_1014.
#
# 3. Operasi Penjumlahan, Pengurangan, & Perkalian: Program menghitung nilai menggunakan operator dasar +, -, dan * secara berurutan, menyimpan hasilnya pada variabel hasil, lalu mencetaknya ke layar dengan print().
#
# 4. Percabangan Pembagian (Pembagian, Floor Division, & Modulo): Kondisi if angka2_1014 != 0 mengecek agar angka kedua bukan nol untuk mencegah error Division by Zero. Jika terpenuhi, program menghitung pembagian desimal (/), pembagian bulat (//), dan sisa bagi/modulo (%). Jika bernilai nol, blok else akan menampilkan pesan peringatan.
#
# 5. Operasi Pangkat: Kode angka1_1014 ** angka2_1014 menggunakan operator ** untuk menghitung perpangkatan dengan angka1_1014 sebagai basis dan angka2_1014 sebagai eksponen, lalu menampilkan hasil akhirnya.

# %% [markdown]
# ### 2.2.2 Program "C_2611531014"

# %%
# Buat file dengan nama Assingment_2611531014.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1014
# program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assignment dalam python

angka1_1014 = int(input("Input angka-1: "))
angka2_1014 = int(input("Input angka-2: "))

print("\nNilai awal angka1 =", angka1_1014)
print("Nilai angka2 =", angka2_1014)

# Assingment biasa 
hasil = angka1_1014
print("\nAssignment baisa (=)")
print("Hasil =", hasil)

# Assignment penambahan
hasil = angka1_1014
hasil += angka2_1014
print("nAssignment penambahan (+=)")
print("Hasil =", hasil)

# Assingment pengurangan
hasil = angka1_1014
hasil -= angka2_1014
print("nAssignment pengurangan (-=)")
print("Hasil =", hasil)

# Assingment perkalian
hasil = angka1_1014
hasil *= angka2_1014
print("nAssignment perkalian (*=)")
print("Hasil =", hasil)

# Assingment pembagian, pembagian bulat, dan sisa bagi
if angka2_1014 != 0:
    hasil = angka1_1014
    hasil /= angka2_1014
    print("nAssignment pembagian (/=)")
    print("Hasil =", hasil)
    # Operator tambahan
    hasil = angka1_1014
    hasil //= angka2_1014
    print("nAssignment pembagian bulat (//=)")
    print("Hasil =", hasil)
    hasil = angka1_1014
    hasil %= angka2_1014
    print("nAssignment sisa bagi (%=)")
    print("Hasil =", hasil)     
else:
    print("\nPembagian tidak dapat dilakukan.")
    print("Angka kedua tidak boleh bernilai 0.")

# Operator tambahan: assignment perpangkatan
hasil = angka1_1014
hasil **= angka2_1014
print("\nAssignment perpangkatan (**=)")
print("Hasil =", hasil)

# %% [markdown]
# **Penjelasan:**
# 1. Komentar & Petunjuk: Baris # berisi dokumentasi program, nama file Assingment_2611531014.py, dan aturan variabel bertag NIM 1014.
#
# 2. Input & Konversi Data: Perintah int(input(...)) mengambil input pengguna lalu mengubah tipe data string menjadi integer untuk disimpan di angka1_1014 dan angka2_1014.
#
# 3. Menampilkan Nilai Awal: Perintah print() menampilkan nilai dasar kedua variabel sebelum diproses lebih lanjut.
#
# 4. Assignment Dasar & Operasi Aritmatika (=, +=, -=, *=): Variabel hasil diisi awal dengan = lalu dihitung secara ringkas menggunakan penugasan penjumlahan (+=), pengurangan (-=), dan perkalian (*=).
#
# 5. Percabangan & Assignment Pembagian (/=, //=, %=): Kondisi if angka2_1014 != 0 mengecek agar pembagi bukan nol, lalu menjalankan assignment pembagian biasa, pembagian bulat, dan modulo. Jika nol, pesan peringatan else akan muncul.
#
# 6. Assignment Perpangkatan (**=): Menghitung perpangkatan variabel hasil dengan eksponen angka2_1014 menggunakan operator **= lalu mencetak hasilnya.

# %% [markdown]
# ### 2.2.3 Program "C_2611531014"

# %%
# Buat file dengan nama bitwise_2611531014.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1014
# program ini menggunakan fungsi input()

print("\n============================")
print("3. OPERATOR BITWISE")
print("==============================")

angka1_1014 = int(input("Masukkan angka bitwise-1: "))
angka2_1014 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1 =", angka1_1014, "| biner =", bin(angka1_1014))
print("angka2 =", angka2_1014, "| biner =", bin(angka2_1014))

# Bitwise AND
hasil = angka1_1014 & angka2_1014
print("\nBitwise AND (&)")
print(angka1_1014, "&", angka2_1014, "=", hasil)
print("Biner hasil =", bin(hasil))
print("Biner hasil (8 bit)=", format(hasil, "08b"))

# Bitwise OR
hasil = angka1_1014 | angka2_1014
print("\nBitwise OR (|)")
print(angka1_1014, "|", angka2_1014, "=", hasil)
print("Biner hasil =", bin(hasil))
print("Biner hasil (8 bit)=", format(hasil, "08b"))

# Bitwise XOR
hasil = angka1_1014 ^ angka2_1014
print("\nBitwise XOR (^)")
print(angka1_1014, "^", angka2_1014, "=", hasil)
print("Biner hasil =", bin(hasil))
print("Biner hasil (8 bit)=", format(hasil, "08b"))

# Bitwise NOT
hasil = ~angka1_1014
print("\nBitwise NOT (~)")
print("~", angka1_1014, "=", hasil)
print("Biner hasil =", bin(hasil))
print("Biner hasil (8 bit)=", format(hasil, "08b"))

# Bitwise geser kiri
jumlah_geser_1014 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil = angka1_1014 << jumlah_geser_1014
print("\nBitwise geser kiri (<<)")
print(angka1_1014, "<<", jumlah_geser_1014, "=", hasil)
print("Biner hasil =", bin(hasil))
print("Biner hasil (8 bit)=", format(hasil, "08b"))

# Bitwise geser kanan
hasil = angka1_1014 >> jumlah_geser_1014
print("\nBitwise geser kanan (>>)")
print(angka1_1014, ">>", jumlah_geser_1014, "=", hasil)
print("Biner hasil =", bin(hasil))
print("Biner hasil (8 bit)=", format(hasil, "08b"))

# %% [markdown]
# **Penjelasan:**
# 1. Komentar & Input Data: Baris awal berfungsi menerima input dua bilangan desimal dari pengguna via int(input()) yang disimpan pada variabel angka1_1014 dan angka2_1014 berakhiran NIM.
#
# 2. Konversi & Tampilan Biner Awal: Menggunakan fungsi bin() untuk mengonversi nilai desimal variabel ke format biner lalu mencetaknya ke layar sebagai acuan perbandingan.
#
# 3. Operasi Bitwise Logika (&, |, ^, ~): Masing-masing bagian ini melakukan operasi logika bit-demi-bit (AND, OR, XOR, dan NOT/Negasi) pada dua nilai. Hasil desimal dan bentuk biner 8-bit (format(hasil, "08b")) langsung dicetak.
#
# 4. Input Jumlah Pergeseran: Perintah input() kedua meminta pengguna memasukkan jumlah nilai pergeseran posisi bit yang disimpan dalam jumlah_geser_1014.
#
# 5. Operasi Bitwise Shift (<<, >>): Melakukan pergeseran bit ke kiri (<<) untuk mengalikan nilai dan pergeseran bit ke kanan (>>) untuk membagi nilai berbasis 2, kemudian menampilkan nilai desimal serta format biner 8-bit hasilnya.

# %% [markdown]
# ### 2.2.4 Program "C_2611531014"

# %%
# Buat file dengan nama lainnya_2611531014.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1014
# program ini menggunakan fungsi input()
# Program operator keanggotaan dan indentitas

print("=================================")
print("1. OPERATOR KEANGGOTAAN")
print("=================================")

# Input beberapa data yang dipisahkan dengan koma
input_data_1014 = input("Masukkan beberapa angka, pisahkan dengan koma: ")

# Mengubah input menjadi list integer
data_1014= [int(angka_1014.strip()) for angka_1014 in input_data_1014.split(",")]

nilai_dicari_1014 = int(input("Masukkan angka yang ingin dicari: "))

# Operator in
hasil_1014= nilai_dicari_1014 in data_1014
print("\nOperator keanggotaan IN")
print(nilai_dicari_1014, "in", data_1014, "=", hasil_1014)

# Operator not in
hasil_1014 = nilai_dicari_1014 not in data_1014
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_1014, "in", data_1014, "=", hasil_1014)


print("=================================")
print("2. OPERATOR IDENTITAS")
print("=================================")

# objek1 menggunakan list dari input pengguna
objek1_1014 = data_1014

# objek2 merujuk pada objek yang sama dengan objek1
objek2_1014 = objek1_1014

# objek3 memiliki isi sama, tetapi merupakan objek baru
objek3_1014 = data_1014.copy()

print("objek1 =", objek1_1014)
print("objek2 =", objek2_1014)
print("objek3 =", objek3_1014)

# Operator is 
hasil = objek1_1014 is objek2_1014
print("\nOperator identitas IS")
print("objek1 is objek2 =", hasil)

# Operator is not
hasil = objek1_1014 is not objek3_1014
print("\nOperator identitas IS NOT")    
print("objek1 is not objek3 =", hasil)

# Membandingkan identitas dan nilai
print("\nMembandingkan identitas dan nilai")
print("objek1 is objek3 =", objek1_1014 is objek3_1014)
print("objek1 == objek3 =", objek1_1014 == objek3_1014)

# %% [markdown]
# **Penjelasan:**
# 1. Pemrosesan Input List, meminta deretan angka berpisah koma, mengonversinya menjadi list integer (data_1014), lalu mengambil angka acuan (nilai_dicari_1014).
#
# 2. Operator Keanggotaan (in & not in), memeriksa ada atau tidaknya angka di dalam list; in menghasilkan True jika ada, sedangkan not in menghasilkan True jika tidak ada.
#
# 3. Inisialisasi Memori Objek, objek2_1014 dibuat merujuk lokasi memori yang sama dengan objek1_1014, sedangkan objek3_1014 disalin via .copy() sehingga menghasilkan objek baru dengan isi yang sama.
#
# 4. Operator Identitas (is & is not), membandingkan apakah dua variabel menunjuk ke alamat memori yang sama (is) atau beda (is not).
#
# 5. Perbandingan Identitas (is) vs Nilai (==), membuktikan bahwa is mengecek kesamaan memori (False untuk objek1 & objek3), sedangkan == mengecek kesamaan isi data (True).

# %% [markdown]
# ### 2.2.5 Program "C_2611531014"

# %%
# Buat file dengan nama logika_2611531014.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1014
# program ini menggunakan fungsi input()
# Program operator logika dalam python

# Memasukkan nilai boolean 
# Input tidak peka terhadap huruf besar dan kecil
a1_1014 = input("Input nilai booelan-1 (true/false): ").strip().lower() == "true"
a2_1014 = input("Input nilai booelan-2 (true/false): ").strip().lower() == "true"

print("\nA1 =", a1_1014)
print("A2 =", a2_1014)

# Konjungsi: bernilai True jika keduanya True
hasil = a1_1014 and a2_1014
print("\nKonjungsi (AND)")
print("A1 and A2 =", hasil)

# Disjungsi: bernilai True jika salah satunya True
hasil = a1_1014 or a2_1014
print("\nDijungsi (OR)")
print("A1 or A2 =",hasil)

# Negasi A1: membalik nilai A1
hasil = not a1_1014
print("\nNegasi A2 (NOT)")
print("not A1 =", hasil)

# Negasi A2: membalik nilai A2
hasil = not a2_1014
print("\nNegasi A2 (NOT)")  
print("not A2 =", hasil)

# XOR: bernilai True jika kedua nilai berbeda
hasil = a1_1014 != a2_1014
print("\nDisjungsi Eksklusif (XOR)")
print("A1 XOR A2 =", hasil)

# %% [markdown]
# **Penjelasan:**
# 1. Input & Konversi Boolean, membaca input teks, mengabaikan kapitalisasi (.strip().lower()), dan mengonversinya menjadi nilai boolean (True/False) pada a1_1014 dan a2_1014.
#
# 2. Menampilkan Nilai Awal, mencetak nilai boolean dasar dari kedua variabel ke layar.
#
# 3. Operator Konjungsi (and), menghasilkan True hanya jika kedua input bernilai True.
#
# 4. Operator Disjungsi (or), menghasilkan True jika salah satu atau kedua input bernilai True.
#
# 5. Operator Negasi (not), membalikkan nilai boolean dasar (True menjadi False atau sebaliknya).
#
# 6. Disjungsi Eksklusif (XOR / !=), menghasilkan True hanya jika nilai kedua input berbeda.

# %% [markdown]
# ### 2.2.6 Program "C_2611531014"

# %%
# Buat file dengan nama Perbandingan_2611531014.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1014
# program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator perbandingan dalam python

angka1_1014 = int(input("input angka-1: "))
angka2_1014 = int(input("input angka-2: "))

# Lebih besar dari 
hasil = angka1_1014 > angka2_1014
print("\nOperator lebih besar dari")
print("angka1 > angka2 =", hasil)

# Lebih kecil dari
hasil = angka1_1014 < angka2_1014
print("\nOperator lebih kecil dari")
print("angka1 < angka2 =", hasil)

# Lebih besar dari atau sama dengan 
hasil = angka1_1014 >= angka2_1014
print("\nOperator lebih besar dari atau sama dengan")
print("angka1 >= angka2 =", hasil)

# Lebih kecil dari atau sama dengan
hasil = angka1_1014 <= angka2_1014
print("\nOperator lebih kecil dari atau sama dengan")
print("angka1 <= angka2 =", hasil)

# Sama dengan
hasil = angka1_1014 == angka2_1014
print("\nOperator sama dengan")
print("angka1 == angka2 =", hasil)

# Tidak sama dengan 
hasil = angka1_1014 != angka2_1014
print("\nOperator tidak sama dengan")
print("angka1 != angka2 =", hasil)

# Tambahan: perbandingan berantai dalam python
hasil = 0 < angka1_1014 < 100
print("\nPerbandingan berantai")
print("0 < angka1 < 100 =", hasil)

hasil = 0 < angka2_1014 < 100
print("0 < angka2 < 100 =", hasil)

# %% [markdown]
# **Penjelasan:**
# 1. Input & Konversi Data, meminta input dua buah bilangan dari pengguna menggunakan fungsi input(), kemudian dikonversi langsung menjadi tipe data integer (int) dan disimpan ke variabel angka1_1014 serta angka2_1014.
#
# 2. Operator Perbandingan Dasar (>, <, >=, <=, ==, !=), menguji hubungan antara angka1_1014 dan angka2_1014 untuk mengecek lebih besar dari (>), lebih kecil dari (<), lebih besar/sama dengan (>=), lebih kecil/sama dengan (<=), kesamaan (==), dan ketidaksamaan (!=). Setiap pengujian menghasilkan nilai boolean (True atau False) yang kemudian dicetak ke layar.
#
# 3. Perbandingan Berantai (Chained Comparison), memeriksa apakah nilai angka1_1014 dan angka2_1014 berada dalam rentang antara 0 dan 100 (secara eksklusif) menggunakan ekspresi berantai 0 < x < 100, lalu menampilkan hasilnya dalam bentuk boolean.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/soal_tugas.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "C_2611531014"

# %%
# Tugas pekan 3 
# Sistem Simulasi Transaksi dan Validasi Akses Toko

print("======================================")
print("   SISTEM TRANSAKSI TOKO    ")
print("======================================")

# Input Data Pelanggan
nama_1014 = input("Masukkan nama pelanggan: ")
status_1014 = input("Masukkan status pelanggan (member/non-member): ").lower()
total_belanja_1014 = float(input("Masukkan total belanja: Rp "))
jumlah_barang_1014 = int(input("Masukkan jumlah barang: "))
kode_promo_1014 = input("Masukkan kode promo: ").upper()

# Data promo
daftar_promo_1014 = ["Hemat10", "Hemat20", "GratisOngkir"]
promo_tersedia_1014 = kode_promo_1014 in daftar_promo_1014
promo_tidak_tersedia_1014 = kode_promo_1014 not in daftar_promo_1014

# Operator Perbandingan
syarat_belanja_1014 = total_belanja_1014 >= 200000
syarat_barang_1014 = jumlah_barang_1014 >= 3
status_member_1014 = status_1014 == "member"

# Operator logika
diskon_member_1014 = status_member_1014 and syarat_belanja_1014
promo_1014 = syarat_belanja_1014 and promo_tersedia_1014
akses_umum_1014 = status_member_1014 and promo_tersedia_1014
bukan_member_1014 = not status_member_1014
mendapat_diskon_1014 = diskon_member_1014 

# Operator aritmatika
if diskon_member_1014:
    diskon_1014 = total_belanja_1014 * 10 / 100
else:
    diskon_1014 = 0
total_pembayaran_1014 = total_belanja_1014 - diskon_1014
if jumlah_barang_1014 > 0:
    rata_rata_harga_1014 = total_belanja_1014 / jumlah_barang_1014
else:
    rata_rata_harga_1014 = 0
sisa_bagi_1014 = jumlah_barang_1014 % 2

#  Operator penugasan
#untuk +=
poin_1014 = 0
poin_1014 += int(total_pembayaran_1014 / 10000) 

#untuk -=
stok_bonus_1014 = 10
if stok_bonus_1014:
    stok_bonus_1014 -= 1

# Operator identity
#untuk is dan is not
objek_1_1014 = ["member", 10]
objek_2_1014 = objek_1_1014
objek_3_1014 = ["member", 10]

identitas_sama_1014 = objek_1_1014 is objek_2_1014
identitas_berbeda_1014 = objek_1_1014 is not objek_3_1014
nilai_sama_1014 = objek_1_1014 == objek_3_1014

# operator bitwise
#untuk nilai bit:
# 0001 = Member
# 0010 = Belanja >= 200000
# 0100 = Jumlah barang >= 3
# 1000 = Kode promo tersedia

kode_member_1014 = 0b0001 
kode_belanja_1014 = 0b0010 
kode_barang_1014 = 0b0100
kode_promo_bit_1014 = 0b1000

kode_status_1014 = 0

#operator or(|) unutk menggabungkan kondisi
if status_member_1014:
    kode_status_1014 = kode_status_1014 | kode_member_1014
if syarat_belanja_1014:
    kode_status_1014 = kode_status_1014 | kode_belanja_1014
if syarat_barang_1014:
    kode_status_1014 = kode_status_1014 | kode_barang_1014
if promo_tersedia_1014:
    kode_status_1014 = kode_status_1014 | kode_promo_bit_1014

#operator and (&) untuk memeriksa kondisi tertentu
cek_member_bit_1014 = kode_status_1014 & kode_member_1014
cek_belanja_bit_1014 = kode_status_1014 & kode_belanja_1014
cek_barang_bit_1014 = kode_status_1014 & kode_barang_1014
cek_promo_bit_1014 = kode_status_1014 & kode_promo_bit_1014

#oprator XOR (^) untuk membandingkan dua kode
kode_referensi_1014 = 0b1011
hasil_xor_1014 = kode_status_1014 ^ kode_referensi_1014

#opertaor shift kiri (<<)
hasil_shift_1014 = kode_status_1014 << 1

# Hak Akses Pelanggan
member_access_1014 = cek_member_bit_1014 == kode_member_1014
promo_access_1014 = cek_promo_bit_1014 == kode_promo_bit_1014

# free shipping jika memiliki promo GratisOngkir
free_shipping_1014 = kode_promo_1014 == "GratisOngkir"

if member_access_1014 and promo_access_1014:
    hak_akses_1014 = "Member + Promo"
elif member_access_1014:
    hak_akses_1014 = "Member"
elif promo_access_1014:
    hak_akses_1014 = "Promo"
else:
    hak_akses_1014 = "Umum"

# Ouput Data Pelanggan
print("\n==========================")
print("  DATA PELANGGAN  ")
print("============================")

print("nama pelanggan :", nama_1014)
print("status pelanggan :", status_1014)
print("total belanja_1014 : Rp", format(total_belanja_1014,".0f"))
print("jumlah barang :", jumlah_barang_1014)
print("kode promo :", kode_promo_1014)

# Hasil Validasi
print("\n==========================")
print("  HASIL VALIDASI  ")
print("============================")

print("belanja >= Rp200000 :", syarat_belanja_1014)
print("jumlah barang >= 3 :", syarat_barang_1014)
print("syarat member :", status_member_1014)
print("kode promo trsedia :", promo_tersedia_1014)
print("mendapatkan diskon :", mendapat_diskon_1014)
print("mendapatkan promo :", promo_1014)

# Hasil Perhitungan
print("\n==========================")
print("  HASIL PERHITUNGAN  ")
print("============================")

print("besarnya diskon : Rp", format(diskon_1014, ".0f"))
print("total pembayaran :Rp", format(total_pembayaran_1014, ".0f"))
print("rata-rata harga barang : Rp", format(rata_rata_harga_1014, ".0f"))
print("sisa jumlah barang / 2 :", sisa_bagi_1014)

# Hasil Operator Logika
print("\n==========================")
print("  OPERATOR LOGIKA  ")
print("============================")

print("member and belanja >= 200000 :", diskon_member_1014)
print("barang >= 3 and promo ada :", promo_1014)
print("member or promo ada :", akses_umum_1014)
print("not member :", bukan_member_1014)

# Operator Assignment
print("\n==========================")
print("  OPERATOR PENUGASAN  ")
print("============================")

print("poin pelanggan (+) :", poin_1014)
print("stok bonus (-) :", stok_bonus_1014)

# Operator Membership
print("\n==========================")
print("  OPERATOR PENUGASAN  ")
print("============================")

print("kode promo in daftar :", promo_tersedia_1014)
print("kode promo not in daftar :", promo_tidak_tersedia_1014)

# Operator identity
print("\n==========================")
print("  OPERATOR IDENTITY  ")
print("============================")

print("objek_1 is objek_2 :", identitas_sama_1014)
print("objek_1 is not objek_3 :", identitas_berbeda_1014)
print("objek_1 == objek_3 :", nilai_sama_1014)

# Operasi Bitwise
print("\n==========================")
print("  OPERATOR BITWISE  ")
print("============================")

print("kode status transaksi")
print("0001 = member")
print("0010 = belanja >= Rp200000")
print("0100 = jumlah barang >= 3")
print("1000 = kode promo tersedia")

print("\nKode Biner :", format(kode_status_1014, "04b"))
print("kode Desimal :", kode_status_1014)

print("\n--- Pemeriksaan Status ---")

print("\ncek member")
print(format(kode_status_1014, "04b"), "&", format(kode_member_1014, "04b"))
print("Hasil Biner :", format(cek_member_bit_1014, "04b"))
print("Hasil Desimal :", cek_member_bit_1014)

print("\nCek Belanja")
print(format(kode_status_1014, "04b"), "&", format(kode_belanja_1014, "04b"))
print("Hasil Biner :", format(cek_belanja_bit_1014, "04b"))
print("Hasil Desimal :", cek_belanja_bit_1014)

print("\nCek jumlah Barang")
print(format(kode_status_1014, "04b"), "&", format(kode_barang_1014, "04b"))
print("Hasil Biner :", format(cek_barang_bit_1014, "04b"))
print("Hasil Desimal :", cek_barang_bit_1014)

print("\nCek Promo")
print(format(kode_status_1014, "04b"), "&", format(kode_promo_bit_1014, "04b"))
print("Hasil Biner :", format(cek_promo_bit_1014, "04b"))
print("Hasil Desimal :", cek_promo_bit_1014)

print("\n---Perbandingan Status XOR ---")
print("Kode Transaksi :", format(kode_status_1014, "04b"))
print("Kode Referensi :", format(kode_referensi_1014, "04b"))
print(format(kode_status_1014, "04b"), "^", format(kode_referensi_1014, "04b"))
print("Hasil Biner :", format(hasil_xor_1014, "04b"))
print("Hasil Desimal :", hasil_xor_1014)

print("\n--- Shift ---")
print(format(kode_status_1014, "04b"), "<< 1")
print("Hasil Biner :", format(hasil_shift_1014))
print("Hasil Desimal :", hasil_shift_1014)

# Hak Akses
print("\n==========================")
print("  HAK AKSES PELANGGAN  ")
print("============================")

print("kode hak akses :", hak_akses_1014)
print("member accsess :", member_access_1014)
print("promo access :", promo_access_1014)
print(" free shipping accsess :", free_shipping_1014)

print("\n==========================")
print("  SELESAI  ")
print("============================")

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/output_tugas.png" width="400"><br>
# <img src="images/output2_tugas.png" width="400"><br>
# <img src="images/output3_tugas.png" width="400"><br>
# <img src="images/output4_tugas.png" width="400"><br>
# <img src="images/output5_tugas.png" width="400"><br>
# <img src="images/output6_tugas.png" width="400"><br>
# <em>Gambar 2.3 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :**
# 1. **Input Data Pelanggan**
# Program menerima input nama, status keanggotaan, total belanja, jumlah barang, dan kode promo. Teks status diubah ke huruf kecil dan kode promo ke huruf kapital agar format data seragam.
# 2. **Pemeriksaan Syarat dan Promo**
# Sistem mengecek apakah kode promo terdaftar di daftar resmi (`Hemat10`, `Hemat20`, `GratisOngkir`). Program juga mengecek kondisi apakah belanja $\ge \text{Rp}200.000$, barang $\ge 3$, dan status pelanggan adalah *member*.
# 3. **Perhitungan Diskon dan Pembayaran**
# Diskon 10% dihitung jika pelanggan adalah *member* sekaligus belanja minimal Rp200.000. Setelah itu, sistem menghitung total bayar akhir dan rata-rata harga barang.
# 4. **Penugasan Poin dan Stok**
# Pelanggan mendapat 1 poin setiap kelipatan bayar Rp10.000 menggunakan operator `+=`. Stok bonus barang juga otomatis dikurangi 1 menggunakan operator `-=`.
# 5. **Pengujian Membership dan Identity**
# Program menguji validasi promo dengan operator `in` / `not in`. Operator `is` dan `==` juga dijalankan untuk membedakan kesamaan identitas memori dengan kesamaan nilai data.
# 6. **Pengolahan Bitwise**
# Kondisi transaksi diubah ke biner 4-bit (member, belanja, barang, promo). Operator `|` menggabungkan kondisi aktif, `&` mengecek kondisi spesifik, `^` membandingkan dengan referensi, dan `<<` menggeser posisi bit.
# 7. **Penentuan Hak Akses**
# Tingkat akses pelanggan ditentukan dari hasil bitwise (*Member + Promo*, *Member*, *Promo*, atau *Umum*). Promo `GratisOngkir` juga diverifikasi untuk memberikan fasilitas bebas ongkir.
# 8. **Pencetakan Laporan Akhir**
# Seluruh hasil input, validasi, perhitungan diskon, operasi bitwise (biner & desimal), dan hak akses akhir ditampilkan secara rapi di layar.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa penggunaan berbagai jenis operator dalam Python—termasuk operator aritmatika, perbandingan, logika, penugasan, keanggotaan, identitas, hingga bitwise—merupakan fondasi utama dalam membangun logika pemrograman yang terstruktur, efisien, dan mampu mengolah berbagai kondisi data secara otomatis.
#
# Dalam konteks pemrograman sistem simulasi transaksi dan validasi akses toko, konsep ini memanfaatkan kombinasi kalkulasi matematika untuk perhitungan finansial, evaluasi nilai kebenaran (*True/False*) untuk pengujian syarat belanja, serta teknik pengolahan status berbasis bit (*bitwise masking*) untuk pengelompokan kondisi transaksi. Hasilnya, program tidak hanya mampu menghitung variabel diskon, poin, dan total pembayaran secara akurat, tetapi juga dapat memverifikasi kualifikasi promo serta menentukan tingkat hak akses pelanggan secara tepat dan responsif sesuai kriteria bisnis yang ditetapkan.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] **Python Software Foundation.** (2024). *Expressions — Python 3 Documentation*. Tersedia secara online: [https://docs.python.org/3/reference/expressions.html](https://docs.python.org/3/reference/expressions.html?utm_source=gemini)
#
# [2] **Python Software Foundation.** (2024). *Built-in Types — Python 3 Documentation*. Tersedia secara online: [https://docs.python.org/3/library/stdtypes.html](https://docs.python.org/3/library/stdtypes.html?utm_source=gemini)
#
# [3] **Severance, C. R.** (2016). *Python for Everybody: Exploring Data in Python 3*. Createspace Independent Publishing Platform.
#
# [4] **Sweigart, A.** (2019). *Automate the Boring Stuff with Python: Practical Programming for Total Beginners* (2nd ed.). No Starch Press.
#
# [5] **Van Rossum, G., & Drake, F. L.** (2009). *An Introduction to Python 3*. Network Theory Ltd.
